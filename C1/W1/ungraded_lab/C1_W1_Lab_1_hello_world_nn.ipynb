# %% [markdown]
# <a href="https://colab.research.google.com/github/https-deeplearning-ai/tensorflow-1-public/blob/master/C1/W1/ungraded_lab/C1_W1_Lab_1_hello_world_nn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Ungraded Lab: The Hello World of Deep Learning with Neural Networks

# %% [markdown]
# Like every first app, you should start with something super simple that shows the overall scaffolding for how your code works. In the case of creating neural networks, one simple case is where it learns the relationship between two numbers. So, for example, if you were writing code for a function like this, you already know the 'rules':
#
#
# ```
# def hw_function(x):
#     y = (2 * x) - 1
#     return y
# ```
#
# So how would you train a neural network to do the equivalent task? By using data! By feeding it with a set of x's and y's, it should be able to figure out the relationship between them.
#
# This is obviously a very different paradigm from what you might be used to. So let's step through it piece by piece.

# %% [markdown]
# ## Imports
#
# Let's start with the imports. Here, you are importing [TensorFlow](https://www.tensorflow.org/) and calling it `tf` for convention and ease of use.
#
# You then import a library called [`numpy`](https://numpy.org) which helps to represent data as arrays easily and to optimize numerical operations.
#
# The framework you will use to build a neural network as a sequence of layers is called [`keras`](https://keras.io/) so you will import that too.

# %%
import tensorflow as tf
import numpy as np
from tensorflow import keras

print(tf.__version__)
# Out:
# 2023-07-01 22:53:14.162697: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2.12.0

# %% [markdown]
# ## Define and Compile the Neural Network
#
# Next, you will create the simplest possible neural network. It has 1 layer with 1 neuron, and the input shape to it is just 1 value. You will build this model using Keras' [Sequential](https://keras.io/api/models/sequential/) class which allows you to define the network as a sequence of [layers](https://keras.io/api/layers/). You can use a single [Dense](https://keras.io/api/layers/core_layers/dense/) layer to build this simple network as shown below.

# %%
# Build a simple Sequential model
model = tf.keras.Sequential([keras.layers.Dense(units=1, input_shape=[1])])

# %% [markdown]
# Now, you will compile the neural network. When you do so, you have to specify 2 functions: a [loss](https://keras.io/api/losses/) and an [optimizer](https://keras.io/api/optimizers/).
#
# If you've seen lots of math for machine learning, here's where it's usually used. But in this case, it's nicely encapsulated in functions and classes for you. But what happens here? Let's explain...
#
# You know that in the function declared at the start of this notebook, the relationship between the numbers is `y=2x-1`. When the computer is trying to 'learn' that, it makes a guess... maybe `y=10x+10`. The `loss` function measures the guessed answers against the known correct answers and measures how well or how badly it did.
#
# It then uses the `optimizer` function to make another guess. Based on how the loss function went, it will try to minimize the loss. At that point maybe it will come up with something like `y=5x+5`, which, while still pretty bad, is closer to the correct result (i.e. the loss is lower).
#
# It will repeat this for the number of _epochs_ which you will see shortly. But first, here's how you will tell it to use [mean squared error](https://keras.io/api/losses/regression_losses/#meansquarederror-function) for the loss and [stochastic gradient descent](https://keras.io/api/optimizers/sgd/) for the optimizer. You don't need to understand the math for these yet, but you can see that they work!
#
# Over time, you will learn the different and appropriate loss and optimizer functions for different scenarios.

# %%
# Compile the model
model.compile(optimizer='sgd', loss='mean_squared_error')

# %% [markdown]
# ## Providing the Data
#
# Next up, you will feed in some data. In this case, you are taking 6 X's and 6 Y's. You can see that the relationship between these is `y=2x-1`, so where `x = -1`, `y=-3` etc.
#
# The de facto standard way of declaring model inputs and outputs is to use `numpy`, a Python library that provides lots of array type data structures. You can specify these values by building numpy arrays with [`np.array()`](https://numpy.org/doc/stable/reference/generated/numpy.array.html).

# %%
# Declare model inputs and outputs for training
xs = np.array([-1.0,  0.0, 1.0, 2.0, 3.0, 4.0], dtype=float)
ys = np.array([-3.0, -1.0, 1.0, 3.0, 5.0, 7.0], dtype=float)

# %% [markdown]
# # Training the Neural Network
#
# The process of training the neural network, where it 'learns' the relationship between the x's and y's is in the [`model.fit()`](https://keras.io/api/models/model_training_apis/#fit-method)  call. This is where it will go through the loop we spoke about above: making a guess, measuring how good or bad it is (aka the loss), using the optimizer to make another guess etc. It will do it for the number of `epochs` you specify. When you run this code, you'll see the loss on the right hand side.

# %%
# Train the model
model.fit(xs, ys, epochs=500)
# Out:
#  0s 3ms/step - loss: 0.0098
# Epoch 258/500
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0096
# Epoch 259/500
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0094
# Epoch 260/500
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0092
# Epoch 261/500
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0091
# Epoch 262/500
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0089
# Epoch 263/500
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0087
# Epoch 264/500
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0085
# Epoch 265/500
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0083
# Epoch 266/500
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0082
# Epoch 267/500
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0080
# Epoch 268/500
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0078
# Epoch 269/500
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0077
# Epoch 270/500
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0075
# Epoch 271/500
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0074
# Epoch 272/500
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0072
# Epoch 273/500
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0071
# Epoch 274/500
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0069
# Epoch 275/500
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0068
# Epoch 276/500
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0066
# Epoch 277/500
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0065
# Epoch 278/500
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0064
# Epoch 279/500
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0062
# Epoch 280/500
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0061
# Epoch 281/500
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0060
# Epoch 282/500
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0059
# Epoch 283/500
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0057
# Epoch 284/500
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0056
# Epoch 285/500
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0055
# Epoch 286/500
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0054
# Epoch 287/500
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0053
# Epoch 288/500
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0052
# Epoch 289/500
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0051
# Epoch 290/500
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0050
# Epoch 291/500
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0049
# Epoch 292/500
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0048
# Epoch 293/500
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0047
# Epoch 294/500
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0046
# Epoch 295/500
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0045
# Epoch 296/500
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0044
# Epoch 297/500
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0043
# Epoch 298/500
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0042
# Epoch 299/500
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0041
# Epoch 300/500
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0040
# Epoch 301/500
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0039
# Epoch 302/500
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0039
# Epoch 303/500
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0038
# Epoch 304/500
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0037
# Epoch 305/500
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0036
# Epoch 306/500
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0036
# Epoch 307/500
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0035
# Epoch 308/500
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0034
# Epoch 309/500
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0033
# Epoch 310/500
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0033
# Epoch 311/500
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0032
# Epoch 312/500
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0031
# Epoch 313/500
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0031
# Epoch 314/500
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0030
# Epoch 315/500
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0030
# Epoch 316/500
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0029
# Epoch 317/500
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0028
# Epoch 318/500
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0028
# Epoch 319/500
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0027
# Epoch 320/500
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0027
# Epoch 321/500
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0026
# Epoch 322/500
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0026
# Epoch 323/500
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0025
# Epoch 324/500
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0024
# Epoch 325/500
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0024
# Epoch 326/500
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0023
# Epoch 327/500
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0023
# Epoch 328/500
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0023
# Epoch 329/500
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0022
# Epoch 330/500
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0022
# Epoch 331/500
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0021
# Epoch 332/500
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0021
# Epoch 333/500
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0020
# Epoch 334/500
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0020
# Epoch 335/500
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0019
# Epoch 336/500
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0019
# Epoch 337/500
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0019
# Epoch 338/500
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0018
# Epoch 339/500
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0018
# Epoch 340/500
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0018
# Epoch 341/500
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0017
# Epoch 342/500
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0017
# Epoch 343/500
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0017
# Epoch 344/500
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0016
# Epoch 345/500
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0016
# Epoch 346/500
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0016
# Epoch 347/500
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0015
# Epoch 348/500
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0015
# Epoch 349/500
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0015
# Epoch 350/500
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0014
# Epoch 351/500
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0014
# Epoch 352/500
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0014
# Epoch 353/500
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0013
# Epoch 354/500
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0013
# Epoch 355/500
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0013
# Epoch 356/500
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0013
# Epoch 357/500
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0012
# Epoch 358/500
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0012
# Epoch 359/500
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0012
# Epoch 360/500
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0012
# Epoch 361/500
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0011
# Epoch 362/500
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0011
# Epoch 363/500
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0011
# Epoch 364/500
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0011
# Epoch 365/500
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0010
# Epoch 366/500
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0010
# Epoch 367/500
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0010
# Epoch 368/500
# 1/1 [==============================] - 0s 3ms/step - loss: 9.8278e-04
# Epoch 369/500
# 1/1 [==============================] - 0s 3ms/step - loss: 9.6260e-04
# Epoch 370/500
# 1/1 [==============================] - 0s 4ms/step - loss: 9.4282e-04
# Epoch 371/500
# 1/1 [==============================] - 0s 3ms/step - loss: 9.2346e-04
# Epoch 372/500
# 1/1 [==============================] - 0s 3ms/step - loss: 9.0449e-04
# Epoch 373/500
# 1/1 [==============================] - 0s 4ms/step - loss: 8.8591e-04
# Epoch 374/500
# 1/1 [==============================] - 0s 5ms/step - loss: 8.6772e-04
# Epoch 375/500
# 1/1 [==============================] - 0s 4ms/step - loss: 8.4989e-04
# Epoch 376/500
# 1/1 [==============================] - 0s 4ms/step - loss: 8.3243e-04
# Epoch 377/500
# 1/1 [==============================] - 0s 4ms/step - loss: 8.1533e-04
# Epoch 378/500
# 1/1 [==============================] - 0s 3ms/step - loss: 7.9859e-04
# Epoch 379/500
# 1/1 [==============================] - 0s 3ms/step - loss: 7.8218e-04
# Epoch 380/500
# 1/1 [==============================] - 0s 4ms/step - loss: 7.6611e-04
# Epoch 381/500
# 1/1 [==============================] - 0s 3ms/step - loss: 7.5038e-04
# Epoch 382/500
# 1/1 [==============================] - 0s 3ms/step - loss: 7.3496e-04
# Epoch 383/500
# 1/1 [==============================] - 0s 4ms/step - loss: 7.1986e-04
# Epoch 384/500
# 1/1 [==============================] - 0s 3ms/step - loss: 7.0508e-04
# Epoch 385/500
# 1/1 [==============================] - 0s 3ms/step - loss: 6.9060e-04
# Epoch 386/500
# 1/1 [==============================] - 0s 4ms/step - loss: 6.7641e-04
# Epoch 387/500
# 1/1 [==============================] - 0s 4ms/step - loss: 6.6252e-04
# Epoch 388/500
# 1/1 [==============================] - 0s 3ms/step - loss: 6.4891e-04
# Epoch 389/500
# 1/1 [==============================] - 0s 4ms/step - loss: 6.3558e-04
# Epoch 390/500
# 1/1 [==============================] - 0s 4ms/step - loss: 6.2253e-04
# Epoch 391/500
# 1/1 [==============================] - 0s 3ms/step - loss: 6.0974e-04
# Epoch 392/500
# 1/1 [==============================] - 0s 3ms/step - loss: 5.9721e-04
# Epoch 393/500
# 1/1 [==============================] - 0s 4ms/step - loss: 5.8495e-04
# Epoch 394/500
# 1/1 [==============================] - 0s 4ms/step - loss: 5.7293e-04
# Epoch 395/500
# 1/1 [==============================] - 0s 3ms/step - loss: 5.6116e-04
# Epoch 396/500
# 1/1 [==============================] - 0s 4ms/step - loss: 5.4964e-04
# Epoch 397/500
# 1/1 [==============================] - 0s 4ms/step - loss: 5.3835e-04
# Epoch 398/500
# 1/1 [==============================] - 0s 3ms/step - loss: 5.2729e-04
# Epoch 399/500
# 1/1 [==============================] - 0s 4ms/step - loss: 5.1646e-04
# Epoch 400/500
# 1/1 [==============================] - 0s 4ms/step - loss: 5.0585e-04
# Epoch 401/500
# 1/1 [==============================] - 0s 4ms/step - loss: 4.9546e-04
# Epoch 402/500
# 1/1 [==============================] - 0s 3ms/step - loss: 4.8529e-04
# Epoch 403/500
# 1/1 [==============================] - 0s 4ms/step - loss: 4.7532e-04
# Epoch 404/500
# 1/1 [==============================] - 0s 4ms/step - loss: 4.6555e-04
# Epoch 405/500
# 1/1 [==============================] - 0s 3ms/step - loss: 4.5599e-04
# Epoch 406/500
# 1/1 [==============================] - 0s 3ms/step - loss: 4.4662e-04
# Epoch 407/500
# 1/1 [==============================] - 0s 4ms/step - loss: 4.3745e-04
# Epoch 408/500
# 1/1 [==============================] - 0s 4ms/step - loss: 4.2846e-04
# Epoch 409/500
# 1/1 [==============================] - 0s 3ms/step - loss: 4.1966e-04
# Epoch 410/500
# 1/1 [==============================] - 0s 3ms/step - loss: 4.1104e-04
# Epoch 411/500
# 1/1 [==============================] - 0s 4ms/step - loss: 4.0260e-04
# Epoch 412/500
# 1/1 [==============================] - 0s 3ms/step - loss: 3.9433e-04
# Epoch 413/500
# 1/1 [==============================] - 0s 3ms/step - loss: 3.8623e-04
# Epoch 414/500
# 1/1 [==============================] - 0s 4ms/step - loss: 3.7830e-04
# Epoch 415/500
# 1/1 [==============================] - 0s 4ms/step - loss: 3.7053e-04
# Epoch 416/500
# 1/1 [==============================] - 0s 3ms/step - loss: 3.6292e-04
# Epoch 417/500
# 1/1 [==============================] - 0s 3ms/step - loss: 3.5546e-04
# Epoch 418/500
# 1/1 [==============================] - 0s 4ms/step - loss: 3.4816e-04
# Epoch 419/500
# 1/1 [==============================] - 0s 4ms/step - loss: 3.4101e-04
# Epoch 420/500
# 1/1 [==============================] - 0s 3ms/step - loss: 3.3401e-04
# Epoch 421/500
# 1/1 [==============================] - 0s 3ms/step - loss: 3.2714e-04
# Epoch 422/500
# 1/1 [==============================] - 0s 4ms/step - loss: 3.2042e-04
# Epoch 423/500
# 1/1 [==============================] - 0s 3ms/step - loss: 3.1384e-04
# Epoch 424/500
# 1/1 [==============================] - 0s 3ms/step - loss: 3.0739e-04
# Epoch 425/500
# 1/1 [==============================] - 0s 4ms/step - loss: 3.0108e-04
# Epoch 426/500
# 1/1 [==============================] - 0s 4ms/step - loss: 2.9490e-04
# Epoch 427/500
# 1/1 [==============================] - 0s 3ms/step - loss: 2.8884e-04
# Epoch 428/500
# 1/1 [==============================] - 0s 4ms/step - loss: 2.8291e-04
# Epoch 429/500
# 1/1 [==============================] - 0s 4ms/step - loss: 2.7709e-04
# Epoch 430/500
# 1/1 [==============================] - 0s 3ms/step - loss: 2.7140e-04
# Epoch 431/500
# 1/1 [==============================] - 0s 3ms/step - loss: 2.6583e-04
# Epoch 432/500
# 1/1 [==============================] - 0s 5ms/step - loss: 2.6037e-04
# Epoch 433/500
# 1/1 [==============================] - 0s 5ms/step - loss: 2.5502e-04
# Epoch 434/500
# 1/1 [==============================] - 0s 3ms/step - loss: 2.4978e-04
# Epoch 435/500
# 1/1 [==============================] - 0s 4ms/step - loss: 2.4465e-04
# Epoch 436/500
# 1/1 [==============================] - 0s 4ms/step - loss: 2.3962e-04
# Epoch 437/500
# 1/1 [==============================] - 0s 3ms/step - loss: 2.3470e-04
# Epoch 438/500
# 1/1 [==============================] - 0s 4ms/step - loss: 2.2988e-04
# Epoch 439/500
# 1/1 [==============================] - 0s 4ms/step - loss: 2.2516e-04
# Epoch 440/500
# 1/1 [==============================] - 0s 3ms/step - loss: 2.2053e-04
# Epoch 441/500
# 1/1 [==============================] - 0s 4ms/step - loss: 2.1600e-04
# Epoch 442/500
# 1/1 [==============================] - 0s 4ms/step - loss: 2.1157e-04
# Epoch 443/500
# 1/1 [==============================] - 0s 3ms/step - loss: 2.0722e-04
# Epoch 444/500
# 1/1 [==============================] - 0s 3ms/step - loss: 2.0296e-04
# Epoch 445/500
# 1/1 [==============================] - 0s 5ms/step - loss: 1.9879e-04
# Epoch 446/500
# 1/1 [==============================] - 0s 5ms/step - loss: 1.9471e-04
# Epoch 447/500
# 1/1 [==============================] - 0s 3ms/step - loss: 1.9071e-04
# Epoch 448/500
# 1/1 [==============================] - 0s 4ms/step - loss: 1.8680e-04
# Epoch 449/500
# 1/1 [==============================] - 0s 4ms/step - loss: 1.8296e-04
# Epoch 450/500
# 1/1 [==============================] - 0s 3ms/step - loss: 1.7920e-04
# Epoch 451/500
# 1/1 [==============================] - 0s 3ms/step - loss: 1.7552e-04
# Epoch 452/500
# 1/1 [==============================] - 0s 4ms/step - loss: 1.7191e-04
# Epoch 453/500
# 1/1 [==============================] - 0s 4ms/step - loss: 1.6838e-04
# Epoch 454/500
# 1/1 [==============================] - 0s 3ms/step - loss: 1.6493e-04
# Epoch 455/500
# 1/1 [==============================] - 0s 4ms/step - loss: 1.6154e-04
# Epoch 456/500
# 1/1 [==============================] - 0s 4ms/step - loss: 1.5822e-04
# Epoch 457/500
# 1/1 [==============================] - 0s 3ms/step - loss: 1.5497e-04
# Epoch 458/500
# 1/1 [==============================] - 0s 3ms/step - loss: 1.5179e-04
# Epoch 459/500
# 1/1 [==============================] - 0s 3ms/step - loss: 1.4867e-04
# Epoch 460/500
# 1/1 [==============================] - 0s 4ms/step - loss: 1.4561e-04
# Epoch 461/500
# 1/1 [==============================] - 0s 4ms/step - loss: 1.4262e-04
# Epoch 462/500
# 1/1 [==============================] - 0s 3ms/step - loss: 1.3969e-04
# Epoch 463/500
# 1/1 [==============================] - 0s 3ms/step - loss: 1.3683e-04
# Epoch 464/500
# 1/1 [==============================] - 0s 3ms/step - loss: 1.3401e-04
# Epoch 465/500
# 1/1 [==============================] - 0s 3ms/step - loss: 1.3126e-04
# Epoch 466/500
# 1/1 [==============================] - 0s 3ms/step - loss: 1.2856e-04
# Epoch 467/500
# 1/1 [==============================] - 0s 4ms/step - loss: 1.2592e-04
# Epoch 468/500
# 1/1 [==============================] - 0s 4ms/step - loss: 1.2334e-04
# Epoch 469/500
# 1/1 [==============================] - 0s 3ms/step - loss: 1.2080e-04
# Epoch 470/500
# 1/1 [==============================] - 0s 3ms/step - loss: 1.1832e-04
# Epoch 471/500
# 1/1 [==============================] - 0s 5ms/step - loss: 1.1589e-04
# Epoch 472/500
# 1/1 [==============================] - 0s 4ms/step - loss: 1.1351e-04
# Epoch 473/500
# 1/1 [==============================] - 0s 3ms/step - loss: 1.1118e-04
# Epoch 474/500
# 1/1 [==============================] - 0s 4ms/step - loss: 1.0890e-04
# Epoch 475/500
# 1/1 [==============================] - 0s 4ms/step - loss: 1.0666e-04
# Epoch 476/500
# 1/1 [==============================] - 0s 3ms/step - loss: 1.0447e-04
# Epoch 477/500
# 1/1 [==============================] - 0s 3ms/step - loss: 1.0232e-04
# Epoch 478/500
# 1/1 [==============================] - 0s 3ms/step - loss: 1.0022e-04
# Epoch 479/500
# 1/1 [==============================] - 0s 3ms/step - loss: 9.8163e-05
# Epoch 480/500
# 1/1 [==============================] - 0s 3ms/step - loss: 9.6147e-05
# Epoch 481/500
# 1/1 [==============================] - 0s 3ms/step - loss: 9.4171e-05
# Epoch 482/500
# 1/1 [==============================] - 0s 4ms/step - loss: 9.2238e-05
# Epoch 483/500
# 1/1 [==============================] - 0s 3ms/step - loss: 9.0344e-05
# Epoch 484/500
# 1/1 [==============================] - 0s 4ms/step - loss: 8.8489e-05
# Epoch 485/500
# 1/1 [==============================] - 0s 4ms/step - loss: 8.6670e-05
# Epoch 486/500
# 1/1 [==============================] - 0s 3ms/step - loss: 8.4890e-05
# Epoch 487/500
# 1/1 [==============================] - 0s 3ms/step - loss: 8.3146e-05
# Epoch 488/500
# 1/1 [==============================] - 0s 4ms/step - loss: 8.1438e-05
# Epoch 489/500
# 1/1 [==============================] - 0s 6ms/step - loss: 7.9766e-05
# Epoch 490/500
# 1/1 [==============================] - 0s 5ms/step - loss: 7.8127e-05
# Epoch 491/500
# 1/1 [==============================] - 0s 5ms/step - loss: 7.6523e-05
# Epoch 492/500
# 1/1 [==============================] - 0s 3ms/step - loss: 7.4950e-05
# Epoch 493/500
# 1/1 [==============================] - 0s 3ms/step - loss: 7.3413e-05
# Epoch 494/500
# 1/1 [==============================] - 0s 3ms/step - loss: 7.1904e-05
# Epoch 495/500
# 1/1 [==============================] - 0s 4ms/step - loss: 7.0427e-05
# Epoch 496/500
# 1/1 [==============================] - 0s 3ms/step - loss: 6.8981e-05
# Epoch 497/500
# 1/1 [==============================] - 0s 3ms/step - loss: 6.7564e-05
# Epoch 498/500
# 1/1 [==============================] - 0s 4ms/step - loss: 6.6175e-05
# Epoch 499/500
# 1/1 [==============================] - 0s 3ms/step - loss: 6.4816e-05
# Epoch 500/500
# 1/1 [==============================] - 0s 3ms/step - loss: 6.3485e-05

# %% [markdown]
# Ok, now you have a model that has been trained to learn the relationship between `x` and `y`. You can use the [`model.predict()`](https://keras.io/api/models/model_training_apis/#predict-method) method to have it figure out the `y` for a previously unknown `x`. So, for example, if `x=10`, what do you think `y` will be? Take a guess before you run this code:

# %%
# Make a prediction
print(model.predict([10.0]))
# Out:
# 1/1 [==============================] - 0s 70ms/step
# [[18.976755]]

# %% [markdown]
# You might have thought `19`, right? But it ended up being a little under. Why do you think that is?
#
# Remember that neural networks deal with probabilities. So given the data that we fed the model with, it calculated that there is a very high probability that the relationship between `x` and `y` is `y=2x-1`, but with only 6 data points we can't know for sure. As a result, the result for 10 is very close to 19, but not necessarily 19.
#
# As you work with neural networks, you'll see this pattern recurring. You will almost always deal with probabilities, not certainties, and will do a little bit of coding to figure out what the result is based on the probabilities, particularly when it comes to classification.
